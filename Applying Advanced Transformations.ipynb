# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
import pandas as pd
df_super_info = pd.read_csv('Data/superhero_info - superhero_info.csv')

df_super_powers = pd.read_csv('Data/superhero_powers - superhero_powers.csv')

# %%
df_super_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %% [markdown]
# ### Separating the Hero|Publisher column into two.

# %%
df_super_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
## save the 2 new columns into the dataframe
df_super_info[['Hero','Publisher']] = df_super_info['Hero|Publisher'].str.split('|',expand=True)
df_super_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
df_super_info = df_super_info.drop(columns = 'Hero|Publisher')

df_super_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %% [markdown]
# ### Creating two new columns out of Measurement: i.e. Height and Weight

# %%
#.str.replace to replace all single quotes
df_super_info['Measurements'] = df_super_info['Measurements'].str.replace("'", '"')

#Applying json.loads to the entire column
df_super_info['Measurements'] = df_super_info['Measurements'].apply(json.loads)

df_super_info['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
df_super_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %% [markdown]
# Now we have to made two columns out of that one column using pd.series

# %%
hei_wei = df_super_info['Measurements'].apply(pd.Series)

hei_wei.head(2)
# Out:
#      Height    Weight
# 0  203.0 cm  441.0 kg
# 1  191.0 cm   65.0 kg

# %%
df_super_info = pd.concat((df_super_info, hei_wei), axis = 1)

df_super_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg
# ...

# %%
df_super_info = df_super_info.drop(columns = 'Measurements', axis = 1)

# %%
df_super_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight
# 0         A-Bomb      Marvel Comics  203.0   441.0
# 1     Abe Sapien  Dark Horse Comics  191.0    65.0
# 2       Abin Sur          DC Comics  185.0    90.0
# 3    Abomination      Marvel Comics  203.0   441.0
# 4  Absorbing Man      Marvel Comics  193.0   122.0

# %%
df_super_info.dtypes
# Out:
# Gender        object
# Race          object
# Alignment     object
# Hair color    object
# Eye color     object
# Skin color    object
# Hero          object
# Publisher     object
# Height        object
# Weight        object
# dtype: object

# %%
df_super_info['Weight'] = df_super_info['Weight'].str.replace('kg', '')

# %%
df_super_info['Height'] = df_super_info['Height'].str.replace('cm','')

# %%
df_super_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight
# 0         A-Bomb      Marvel Comics  203.0   441.0
# 1     Abe Sapien  Dark Horse Comics  191.0    65.0
# 2       Abin Sur          DC Comics  185.0    90.0
# 3    Abomination      Marvel Comics  203.0   441.0
# 4  Absorbing Man      Marvel Comics  193.0   122.0

# %%
#converting height into int
#df['SibSp'] = df['SibSp'].astype(int)
df_super_info['Weight'] = df_super_info['Weight'].astype(float)

# %%
df_super_info['Height'] = df_super_info['Height'].astype(float)

# %%
df_super_info.dtypes
# Out:
# Gender         object
# Race           object
# Alignment      object
# Hair color     object
# Eye color      object
# Skin color     object
# Hero           object
# Publisher      object
# Height        float64
# Weight        float64
# dtype: object

# %% [markdown]
# Doing one-hot-encoding on Powers columns in df_super_powers

# %%
df_super_powers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
df_super_powers.head(3)
# Out:
#    hero_names                                             Powers
# 0     3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1      A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2  Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...

# %%
## adding expand=True
df_super_powers['Powers_split'] = df_super_powers['Powers'].str.split(',')

df_super_powers.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
df_super_powers['Powers_split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
## exploding the column of lists
exploded = df_super_powers.explode('Powers_split')
exploded.head(5)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
#saving the unique values from the Powers_split column
unique_powers_col = exploded['Powers_split'].dropna().unique()

unique_powers_col
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in unique_powers_col:
    df_super_powers[col] = df_super_powers['Powers'].str.contains(col)
df_super_powers.head()

#might have to scroll down to find the dataset.
# Out:
# /var/folders/0l/_7plg1px5251fbm6lrxyvb580000gn/T/ipykernel_1951/1610156453.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_super_powers[col] = df_super_powers['Powers'].str.contains(col)
# /var/folders/0l/_7plg1px5251fbm6lrxyvb580000gn/T/ipykernel_1951/1610156453.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_super_powers[col] = df_super_powers['Powers'].str.contains(col)
# ...

# %%
df_super_powers = df_super_powers.drop(columns = ['Powers','Powers_split'])
df_super_powers
# Out:
#           hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0            3-D Man     True            True     True         True
# 1             A-Bomb    False            True     True        False
# 2         Abe Sapien     True            True     True        False
# 3           Abin Sur    False           False    False        False
# 4        Abomination    False            True     True         True
# ..               ...      ...             ...      ...          ...
# 662  Yellowjacket II    False           False    False        False
# 663             Ymir    False            True    False        False
# 664             Yoda     True           False     True         True
# 665          Zatanna    False           False    False        False
# 666             Zoom    False           False    False         True
#
#      Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# ...

# %%
df_super_powers.to_csv('advanced_super_powers_data_pt1.csv', index=False)

# %%
df_super_info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher  Height  Weight
# 0      Unknown           A-Bomb      Marvel Comics   203.0   441.0
# ...

# %%
power_assemble = pd.merge(df_super_info, df_super_powers, left_on = 'Hero', right_on = 'hero_names' )

# %%
power_assemble.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %% [markdown]
# ### Compare the average weight of super powers who have Super Speed to those who do not.

# %%
hero_with_Super_Speed = power_assemble.loc[power_assemble['Super Speed'] == True]

print(f" Weight of superheros with Super Speed is: {hero_with_Super_Speed['Weight'].mean()}")
# Out:
#  Weight of superheros with Super Speed is: 129.40404040404042

# %%
hero_with_NO_Super_speed = power_assemble.loc[power_assemble['Super Speed'] == False]

print(f" Weight of superheros with not Super Speed is: {hero_with_NO_Super_speed['Weight'].mean()}")
# Out:
#  Weight of superheros with not Super Speed is: 101.77358490566037

# %% [markdown]
# ### What is the average height of heroes for each publisher?

# %%
power_assemble['Publisher'].value_counts()
# Out:
# Marvel Comics        297
# DC Comics            138
# Dark Horse Comics     11
# George Lucas           5
# Team Epic TV           4
# Shueisha               4
# Star Trek              2
# Unknown                1
# Image Comics           1
# Name: Publisher, dtype: int64

# %%
#making a variable with only the Publisher and height 
pub_height = power_assemble[['Publisher','Height']]

pub_height.head()
# Out:
#            Publisher  Height
# 0      Marvel Comics   203.0
# 1  Dark Horse Comics   191.0
# 2          DC Comics   185.0
# 3      Marvel Comics   203.0
# 4      Marvel Comics   193.0

# %%
pub_height.groupby('Publisher').mean().round(1)
# Out:
#                    Height
# Publisher
# DC Comics           181.9
# Dark Horse Comics   176.9
# George Lucas        159.6
# Image Comics        211.0
# Marvel Comics       191.5
# Shueisha            171.5
# Star Trek           181.5
# Team Epic TV        180.8
# Unknown             178.0
